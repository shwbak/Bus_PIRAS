# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd "/content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/docker_files/fs_get_on_off"
# Out:
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/docker_files/fs_get_on_off

# %% [markdown]
# #아래 세개 셀은 raw 데이터를 의도분석 모델 입력값으로의 변환을 위해 처음에만 쓰는 것!

# %%
#@title Utils 폴더의 data에서 찾아온 코드: __getOriginalDataList 메소드 입력 부분 약간 튜닝 
#from utils.data import GetOnOffData

#__getOriginalDataList 메소드 입력 부분 약간 튜닝 
from __future__ import print_function
from __future__ import absolute_import
from __future__ import division

from glob import glob
import os
from tqdm import tqdm
from functools import cmp_to_key
import json
import random
import math
import numpy as np
from datetime import datetime
from pytz import timezone
import shutil
from tensorflow import keras
import logging
import traceback
logging.basicConfig(level=logging.ERROR)


class GetOnOffData2:
    def __init__(self, original_data_dir, get_on_off_data_dir, dataset_dir, train_val_rate):
        self.original_data_list = self.__getOriginalDataList(original_data_dir)
        self.original_data_dir = original_data_dir
        self.get_on_off_data_dir = get_on_off_data_dir
        self.train_val_rate = train_val_rate
        self.original_num = 0
        self.get_on_json_list = []
        self.get_off_json_list = []
        self.idle_json_list = []
        self.get_on_num = 0
        self.get_off_num = 0
        self.idle_num = 0
        self.dataset_dir = dataset_dir
        self.train_get_on_num = 0
        self.val_get_on_num = 0
        self.test_get_on_num = 0
        self.train_get_off_num = 0
        self.val_get_off_num = 0
        self.test_get_off_num = 0
        self.train_idle_num = 0
        self.val_idle_num = 0
        self.test_idle_num = 0
        self.train_num = 0
        self.val_num = 0
        self.test_num = 0
        self.train_list = []
        self.val_list = []
        self.test_list = []


    def compare_json(self, x, y):
        x_index = [pos for pos, char in enumerate(x) if char == '_']
        x_index = x_index[-1]
        x_index += 1
        y_index = [pos for pos, char in enumerate(y) if char == '_']
        y_index = y_index[-1]
        y_index += 1
        x_int = int(x[x_index:-5])
        y_int = int(y[y_index:-5])
        if (x_int < y_int):
            return -1
        elif (x_int >= y_int):
            return 1

    def __getOriginalDataList(self, original_data_dir):
        # Get Folder List
        folder_list = glob(original_data_dir + '/*')
        folder_list = [file for file in folder_list if os.path.isdir(file)]
        folder_list = sorted(folder_list)
        random.seed(0)
        random.shuffle(folder_list)

        # list parameters
        dst = []

        for folder in tqdm(folder_list):
            # Json file list
            json_list = os.listdir(folder)
            json_list = [file for file in json_list if file.endswith('.json')]
            json_list = sorted(json_list, key=cmp_to_key(self.compare_json))

            # Get json path
            tmp_list = []
            for json_file_name in json_list:
                tmp_list.append(os.path.join(folder, json_file_name))

            dst.append(tmp_list)

        return dst

    def getOriginalDataLog(self):
        dst = ''
        json_count = 0
        for folder in self.original_data_list:
            for json_path in folder:
                json_count += 1
                dst += str(json_count) + '. ' + json_path + '\n'
                print(str(json_count) + '. ' + json_path)
        self.original_num = json_count

        return dst

    def makeGetOnOffData(self):
        # Make dir
        get_on_dir = os.path.join(self.get_on_off_data_dir, 'get_on')
        get_off_dir = os.path.join(self.get_on_off_data_dir, 'get_off')
        idle_dir = os.path.join(self.get_on_off_data_dir, 'idle')
        os.makedirs(get_on_dir, exist_ok=True)
        os.makedirs(get_off_dir, exist_ok=True)
        os.makedirs(idle_dir, exist_ok=True)

        # Count Parameters
        get_on_count = 0
        get_off_count = 0
        idle_count = 0

        # file name parameters
        get_on_data_name = 'get_on_'
        get_off_data_name = 'get_off_'
        idle_data_name = 'idle_'

        # Make get on off data
        for json_list in tqdm(self.original_data_list):
            # Get Passenger Data
            for i in range(len(json_list) - 2):
                # Get Json data
                json_path_1 = os.path.join(json_list[i])
                json_path_2 = os.path.join(json_list[i + 1])
                json_path_3 = os.path.join(json_list[i + 2])
                try:
                    with open(json_path_1, 'r') as json_file:
                        json_data_1 = json.load(json_file)
                except Exception:
                    raise Exception('json_path_1: ', json_path_1)
                try:
                    with open(json_path_2, 'r') as json_file:
                        json_data_2 = json.load(json_file)
                except Exception:
                    raise Exception('json_path_2: ', json_path_2)
                try:
                    with open(json_path_3, 'r') as json_file:
                        json_data_3 = json.load(json_file)
                except Exception:
                    raise Exception('json_path_3: ', json_path_3)

                # Get Img width & height
                width = json_data_1['info']['width']
                height = json_data_1['info']['height']

                # Get Valid data id and Append data
                if len(json_data_1['annotations']) != 0 and len(json_data_2['annotations']) != 0 and len(
                        json_data_3['annotations']) != 0:
                    for annotation_1 in json_data_1['annotations']:
                        id_1 = annotation_1['id']
                        for annotation_2 in json_data_2['annotations']:
                            id_2 = annotation_2['id']
                            if id_1 != id_2:
                                continue
                            else:
                                for annotation_3 in json_data_3['annotations']:
                                    id_3 = annotation_3['id']
                                    if id_2 != id_3:
                                        continue
                                    else:
                                        # Checking neck keypoint is exist
                                        if annotation_1['keypoints'][26] == 0 and annotation_2['keypoints'][26] == 0 and \
                                                annotation_3['keypoints'][26] == 0:
                                            break
                                        # Checking head keypoint is exist
                                        elif annotation_1['keypoints'][29] == 0 and annotation_2['keypoints'][
                                            29] == 0 and annotation_3['keypoints'][29] == 0:
                                            break
                                        # Checking right shoulder keypoint is exist
                                        elif annotation_1['keypoints'][38] == 0 and annotation_2['keypoints'][
                                            38] == 0 and annotation_3['keypoints'][38] == 0:
                                            break
                                        # Checking left shoulder keypoint is exist
                                        elif annotation_1['keypoints'][41] == 0 and annotation_2['keypoints'][
                                            41] == 0 and annotation_3['keypoints'][41] == 0:
                                            break

                                        # Get Data of neck keypoint
                                        neck_x_1 = annotation_1['keypoints'][24] / width
                                        neck_y_1 = annotation_1['keypoints'][25] / height
                                        neck_x_2 = annotation_2['keypoints'][24] / width
                                        neck_y_2 = annotation_2['keypoints'][25] / height
                                        neck_x_3 = annotation_3['keypoints'][24] / width
                                        neck_y_3 = annotation_3['keypoints'][25] / height

                                        # Get Data of head keypoint
                                        head_x_1 = annotation_1['keypoints'][27] / width
                                        head_y_1 = annotation_1['keypoints'][28] / height
                                        head_x_2 = annotation_2['keypoints'][27] / width
                                        head_y_2 = annotation_2['keypoints'][28] / height
                                        head_x_3 = annotation_3['keypoints'][27] / width
                                        head_y_3 = annotation_3['keypoints'][28] / height

                                        # Get Data of right shoulder keypoint
                                        r_shoulder_x_1 = annotation_1['keypoints'][36] / width
                                        r_shoulder_y_1 = annotation_1['keypoints'][37] / height
                                        r_shoulder_x_2 = annotation_2['keypoints'][36] / width
                                        r_shoulder_y_2 = annotation_2['keypoints'][37] / height
                                        r_shoulder_x_3 = annotation_3['keypoints'][36] / width
                                        r_shoulder_y_3 = annotation_3['keypoints'][37] / height

                                        # Get Data of left shoulder keypoint
                                        l_shoulder_x_1 = annotation_1['keypoints'][39] / width
                                        l_shoulder_y_1 = annotation_1['keypoints'][40] / height
                                        l_shoulder_x_2 = annotation_2['keypoints'][39] / width
                                        l_shoulder_y_2 = annotation_2['keypoints'][40] / height
                                        l_shoulder_x_3 = annotation_3['keypoints'][39] / width
                                        l_shoulder_y_3 = annotation_3['keypoints'][40] / height

                                        # Get Vector of neck->rShoulder
                                        vector_r_shoulder_x_1 = r_shoulder_x_1 - neck_x_1
                                        vector_r_shoulder_y_1 = r_shoulder_y_1 - neck_y_1
                                        vector_r_shoulder_x_2 = r_shoulder_x_2 - neck_x_2
                                        vector_r_shoulder_y_2 = r_shoulder_y_2 - neck_y_2
                                        vector_r_shoulder_x_3 = r_shoulder_x_3 - neck_x_3
                                        vector_r_shoulder_y_3 = r_shoulder_y_3 - neck_y_3

                                        # Get Vector of neck->lShoulder
                                        vector_l_shoulder_x_1 = l_shoulder_x_1 - neck_x_1
                                        vector_l_shoulder_y_1 = l_shoulder_y_1 - neck_y_1
                                        vector_l_shoulder_x_2 = l_shoulder_x_2 - neck_x_2
                                        vector_l_shoulder_y_2 = l_shoulder_y_2 - neck_y_2
                                        vector_l_shoulder_x_3 = l_shoulder_x_3 - neck_x_3
                                        vector_l_shoulder_y_3 = l_shoulder_y_3 - neck_y_3

                                        # Get Vector of neck->head
                                        vector_head_x_1 = head_x_1 - neck_x_1
                                        vector_head_y_1 = head_y_1 - neck_y_1
                                        vector_head_x_2 = head_x_2 - neck_x_2
                                        vector_head_y_2 = head_y_2 - neck_y_2
                                        vector_head_x_3 = head_x_3 - neck_x_3
                                        vector_head_y_3 = head_y_3 - neck_y_3

                                        # Push Data
                                        data = [[0 for col in range(8)] for row in range(3)]
                                        data[0] = [neck_x_1, neck_y_1,
                                                   vector_head_x_1, vector_head_y_1,
                                                   vector_r_shoulder_x_1, vector_r_shoulder_y_1,
                                                   vector_l_shoulder_x_1, vector_l_shoulder_y_1]
                                        data[1] = [neck_x_2, neck_y_2,
                                                   vector_head_x_2, vector_head_y_2,
                                                   vector_r_shoulder_x_2, vector_r_shoulder_y_2,
                                                   vector_l_shoulder_x_2, vector_l_shoulder_y_2]
                                        data[2] = [neck_x_3, neck_y_3,
                                                   vector_head_x_3, vector_head_y_3,
                                                   vector_r_shoulder_x_3, vector_r_shoulder_y_3,
                                                   vector_l_shoulder_x_3, vector_l_shoulder_y_3]

                                        data_dict = dict()
                                        data_dict['data'] = data
                                        data_dict['original_data'] = []
                                        for i in range(3):
                                            tmp_dict = dict()
                                            tmp_dict['time_step'] = i + 1
                                            if i == 0:
                                                tmp_dict['original_data_path'] = json_path_1
                                            elif i == 1:
                                                tmp_dict['original_data_path'] = json_path_2
                                            else:
                                                tmp_dict['original_data_path'] = json_path_3
                                            tmp_dict['id'] = annotation_3['id']

                                            data_dict['original_data'].append(tmp_dict)


                                        # Count num of get_on get_off idle
                                        if annotation_3['get_on']:
                                            get_on_count += 1
                                            data_dict['label'] = 0
                                            json_file_name = get_on_data_name + str(get_on_count) + '.json'
                                            json_file_path = os.path.join(get_on_dir, json_file_name)
                                            if not os.path.exists(json_file_path):
                                                with open(json_file_path, 'w') as f:
                                                    json.dump(data_dict, f, indent=4)

                                        elif annotation_3['get_off']:
                                            get_off_count += 1
                                            data_dict['label'] = 1
                                            json_file_name = get_off_data_name + str(get_off_count) + '.json'
                                            json_file_path = os.path.join(get_off_dir, json_file_name)
                                            if not os.path.exists(json_file_path):
                                                with open(json_file_path, 'w') as f:
                                                    json.dump(data_dict, f, indent=4)

                                        else:
                                            idle_count += 1
                                            data_dict['label'] = 2
                                            json_file_name = idle_data_name + str(idle_count) + '.json'
                                            json_file_path = os.path.join(idle_dir, json_file_name)
                                            if not os.path.exists(json_file_path):
                                                with open(json_file_path, 'w') as f:
                                                    json.dump(data_dict, f, indent=4)

                                        break
                            break

        self.get_on_num = get_on_count
        self.get_off_num = get_off_count
        self.idle_num = idle_count

    def getGetOnDataLog(self):
        dst = ''

        # Get dir
        get_on_dir = os.path.join(self.get_on_off_data_dir, 'get_on')

        # Get json list
        json_list = glob(get_on_dir + '/*')
        json_list = sorted(json_list, key=cmp_to_key(self.compare_json))
        self.get_on_json_list = json_list

        for i in range(self.get_on_num):
            tmp_str = str(i + 1) + '. ' + json_list[i] + '\n'
            with open(json_list[i], 'r') as f:
                json_data = json.load(f)
            for original_data_dict in json_data['original_data']:
                time_step = original_data_dict['time_step']
                original_data_path = original_data_dict['original_data_path']
                id = original_data_dict['id']
                tmp_str += '\ttime_step: {0:d}, original_data_path: {1:s}, id: {2:d}\n'.format(time_step, original_data_path, id)
            dst += tmp_str
            print(tmp_str)

        return dst

    def getGetOffDataLog(self):
        dst = ''

        # Get dir
        get_off_dir = os.path.join(self.get_on_off_data_dir, 'get_off')

        # Get json list
        json_list = glob(get_off_dir + '/*')
        json_list = sorted(json_list, key=cmp_to_key(self.compare_json))
        self.get_off_json_list = json_list

        for i in range(self.get_off_num):
            tmp_str = str(i + 1) + '. ' + json_list[i] + '\n'
            with open(json_list[i], 'r') as f:
                json_data = json.load(f)
            for original_data_dict in json_data['original_data']:
                time_step = original_data_dict['time_step']
                original_data_path = original_data_dict['original_data_path']
                id = original_data_dict['id']
                tmp_str += '\ttime_step: {0:d}, original_data_path: {1:s}, id: {2:d}\n'.format(time_step, original_data_path, id)
            dst += tmp_str
            print(tmp_str)

        return dst

    def getIdleDataLog(self):
        dst = ''

        # Get dir
        idle_dir = os.path.join(self.get_on_off_data_dir, 'idle')

        # Get json list
        json_list = glob(idle_dir + '/*')
        json_list = sorted(json_list, key=cmp_to_key(self.compare_json))
        self.idle_json_list = json_list

        for i in range(self.idle_num):
            tmp_str = str(i + 1) + '. ' + json_list[i] + '\n'
            with open(json_list[i], 'r') as f:
                json_data = json.load(f)
            for original_data_dict in json_data['original_data']:
                time_step = original_data_dict['time_step']
                original_data_path = original_data_dict['original_data_path']
                id = original_data_dict['id']
                tmp_str += '\ttime_step: {0:d}, original_data_path: {1:s}, id: {2:d}\n'.format(time_step, original_data_path, id)
            dst += tmp_str
            print(tmp_str)

        return dst

    def divideDataByRate(self):
        # Get train/val/test dir and make dir
        train_dir = os.path.join(self.dataset_dir, 'training')
        val_dir = os.path.join(self.dataset_dir, 'validation')
        test_dir = os.path.join(self.dataset_dir, 'test')
        os.makedirs(train_dir, exist_ok=True)
        os.makedirs(val_dir, exist_ok=True)
        os.makedirs(test_dir, exist_ok=True)

        # Divide data by rate
        self.train_get_on_num = math.ceil(self.get_on_num * self.train_val_rate[0])  # 올림
        self.val_get_on_num = math.floor(self.get_on_num * self.train_val_rate[1])  # 내림
        self.test_get_on_num = self.get_on_num - self.train_get_on_num - self.val_get_on_num

        self.train_get_off_num = math.ceil(self.get_off_num * self.train_val_rate[0])  # 올림
        self.val_get_off_num = math.floor(self.get_off_num * self.train_val_rate[1])  # 내림
        self.test_get_off_num = self.get_off_num - self.train_get_off_num - self.val_get_off_num

        self.train_idle_num = math.ceil(self.idle_num * self.train_val_rate[0])  # 올림
        self.val_idle_num = math.floor(self.idle_num * self.train_val_rate[1])  # 내림
        self.test_idle_num = self.idle_num - self.train_idle_num - self.val_idle_num

        self.train_num = self.train_get_on_num + self.train_get_off_num + self.train_idle_num
        self.val_num = self.val_get_on_num + self.val_get_off_num + self.val_idle_num
        self.test_num = self.test_get_on_num + self.test_get_off_num + self.test_idle_num

        # Get train/val/test list
        train_json_list = self.get_on_json_list[:self.train_get_on_num] + \
                          self.get_off_json_list[:self.train_get_off_num] + \
                          self.idle_json_list[:self.train_idle_num]

        val_json_list = self.get_on_json_list[self.train_get_on_num:self.train_get_on_num + self.val_get_on_num] + \
                        self.get_off_json_list[self.train_get_off_num:self.train_get_off_num + self.val_get_off_num] + \
                        self.idle_json_list[self.train_idle_num:self.train_idle_num + self.val_idle_num]

        test_json_list = self.get_on_json_list[self.train_get_on_num + self.val_get_on_num:] + \
                         self.get_off_json_list[self.train_get_off_num + self.val_get_off_num:] + \
                         self.idle_json_list[self.train_idle_num + self.val_idle_num:]

        # Copy get_on/get_off/idle json files to train/validation/test dataset dir
        for json_path in tqdm(train_json_list):
            new_json_path = os.path.join(train_dir, os.path.basename(json_path))
            self.train_list.append(new_json_path)
            if not os.path.exists(new_json_path):
                shutil.copyfile(json_path, new_json_path)
        for json_path in tqdm(val_json_list):
            new_json_path = os.path.join(val_dir, os.path.basename(json_path))
            self.val_list.append(new_json_path)
            if not os.path.exists(new_json_path):
                shutil.copyfile(json_path, new_json_path)
        for json_path in tqdm(test_json_list):
            new_json_path = os.path.join(test_dir, os.path.basename(json_path))
            self.test_list.append(new_json_path)
            if not os.path.exists(new_json_path):
                shutil.copyfile(json_path, new_json_path)

    def getTrainDataLog(self):
        dst = ''
        for idx in range(self.train_num):
            json_path = self.train_list[idx]
            dst += '{0:d}. {1:s}'.format(idx + 1, json_path) + '\n'
            print('{0:d}. {1:s}'.format(idx + 1, json_path))
        return dst

    def getValDataLog(self):
        dst = ''
        for idx in range(self.val_num):
            json_path = self.val_list[idx]
            dst += '{0:d}. {1:s}'.format(idx + 1, json_path) + '\n'
            print('{0:d}. {1:s}'.format(idx + 1, json_path))
        return dst

    def getTestDataLog(self):
        dst = ''
        for idx in range(self.test_num):
            json_path = self.test_list[idx]
            dst += '{0:d}. {1:s}'.format(idx + 1, json_path) + '\n'
            print('{0:d}. {1:s}'.format(idx + 1, json_path))
        return dst

    def generateGetOnOffData(self):
        # Parameters
        fmt = '%Y-%m-%d %H:%M:%S %Z%z'
        log_str = ''

        # Get Original Data Log str
        cur_time = datetime.now(timezone('Asia/Seoul')).strftime(fmt)
        timestamp_str = '{0:s}'.format('[Timestamp: ' + cur_time + ']')
        tmp_str = timestamp_str + ' 원본 데이터 파일 목록'
        log_str += tmp_str + '\n'
        print(tmp_str)

        original_data_log_str = self.getOriginalDataLog()
        log_str += original_data_log_str + '\n'

        # Start making get_on, get_off, idle data
        cur_time = datetime.now(timezone('Asia/Seoul')).strftime(fmt)
        timestamp_str = '{0:s}'.format('[Timestamp: ' + cur_time + ']')
        tmp_str = timestamp_str + ' 승하차 데이터 가공 시작'
        log_str += tmp_str + '\n'
        print(tmp_str)

        self.makeGetOnOffData()

        # Get get_on data list
        cur_time = datetime.now(timezone('Asia/Seoul')).strftime(fmt)
        timestamp_str = '{0:s}'.format('[Timestamp: ' + cur_time + ']')
        tmp_str = timestamp_str + ' 승차(Get On) 데이터 파일 목록 및 사용된 원본 데이터 목록'
        log_str += tmp_str + '\n'
        print(tmp_str)

        get_on_log_str = self.getGetOnDataLog()
        log_str += get_on_log_str + '\n'

        # Get get_off data list
        cur_time = datetime.now(timezone('Asia/Seoul')).strftime(fmt)
        timestamp_str = '{0:s}'.format('[Timestamp: ' + cur_time + ']')
        tmp_str = timestamp_str + ' 하차(Get Off) 데이터 파일 목록 및 사용된 원본 데이터 목록'
        log_str += tmp_str + '\n'
        print(tmp_str)

        get_off_log_str = self.getGetOffDataLog()
        log_str += get_off_log_str + '\n'

        # Get Idle data list
        cur_time = datetime.now(timezone('Asia/Seoul')).strftime(fmt)
        timestamp_str = '{0:s}'.format('[Timestamp: ' + cur_time + ']')
        tmp_str = timestamp_str + ' 무관(Idle) 데이터 파일 목록 및 사용된 원본 데이터 목록'
        log_str += tmp_str + '\n'
        print(tmp_str)

        idle_log_str = self.getIdleDataLog()
        log_str += idle_log_str + '\n'

        # Start divide training, validation, test data
        cur_time = datetime.now(timezone('Asia/Seoul')).strftime(fmt)
        timestamp_str = '{0:s}'.format('[Timestamp: ' + cur_time + ']')
        tmp_str = timestamp_str + ' Training(80%)/Validation(10%)/Test(10%) 데이터 분할 시작'
        log_str += tmp_str + '\n'
        print(tmp_str)

        self.divideDataByRate()

        # Get train data list
        cur_time = datetime.now(timezone('Asia/Seoul')).strftime(fmt)
        timestamp_str = '{0:s}'.format('[Timestamp: ' + cur_time + ']')
        tmp_str = timestamp_str + ' Training(80%) 데이터 파일 목록'
        log_str += tmp_str + '\n'
        print(tmp_str)

        train_log_str = self.getTrainDataLog()
        log_str += train_log_str + '\n'

        # Get val data list
        cur_time = datetime.now(timezone('Asia/Seoul')).strftime(fmt)
        timestamp_str = '{0:s}'.format('[Timestamp: ' + cur_time + ']')
        tmp_str = timestamp_str + ' Validation(10%) 데이터 파일 목록'
        log_str += tmp_str + '\n'
        print(tmp_str)

        val_log_str = self.getValDataLog()
        log_str += val_log_str + '\n'

        # Get test data list
        cur_time = datetime.now(timezone('Asia/Seoul')).strftime(fmt)
        timestamp_str = '{0:s}'.format('[Timestamp: ' + cur_time + ']')
        tmp_str = timestamp_str + ' Test(10%) 데이터 파일 목록'
        log_str += tmp_str + '\n'
        print(tmp_str)

        test_log_str = self.getTestDataLog()
        log_str += test_log_str + '\n'

        # summary of data
        cur_time = datetime.now(timezone('Asia/Seoul')).strftime(fmt)
        timestamp_str = '{0:s}'.format('[Timestamp: ' + cur_time + ']')
        tmp_str = timestamp_str + ' 데이터 요약'
        log_str += tmp_str + '\n'
        print(tmp_str)

        tmp_str = '원본 데이터 JSON 파일 개수: {}'.format(str(self.original_num))
        log_str += tmp_str + '\n'
        print(tmp_str)

        tmp_str = '승차(Get On) 데이터 JSON 파일 개수: {}'.format(str(self.get_on_num))
        log_str += tmp_str + '\n'
        print(tmp_str)

        tmp_str = '하차(Get Off) 데이터 JSON 파일 개수: {}'.format(str(self.get_off_num))
        log_str += tmp_str + '\n'
        print(tmp_str)

        tmp_str = '무관(Idle) 데이터 JSON 파일 개수: {}'.format(str(self.idle_num))
        log_str += tmp_str + '\n'
        print(tmp_str)

        tmp_str = 'Training(80%) 데이터 JSON 파일 개수: {} (Get On: {}, Get Off: {}, Idle: {})'.format(
            self.train_num,
            self.train_get_on_num,
            self.train_get_off_num,
            self.train_idle_num
        )
        log_str += tmp_str + '\n'
        print(tmp_str)

        tmp_str = 'Validation(10%) 데이터 JSON 파일 개수: {} (Get On: {}, Get Off: {}, Idle: {})'.format(
            self.val_num,
            self.val_get_on_num,
            self.val_get_off_num,
            self.val_idle_num
        )
        log_str += tmp_str + '\n'
        print(tmp_str)

        tmp_str = 'Test(10%) 데이터 JSON 파일 개수: {} (Get On: {}, Get Off: {}, Idle: {})'.format(
            self.test_num,
            self.test_get_on_num,
            self.test_get_off_num,
            self.test_idle_num
        )
        log_str += tmp_str + '\n'
        print(tmp_str)

        cur_time = datetime.now(timezone('Asia/Seoul')).strftime(fmt)
        timestamp_str = '{0:s}'.format('[Timestamp: ' + cur_time + ']')
        tmp_str = timestamp_str + ' 데이터 가공 완료'
        log_str += tmp_str + '\n\n'
        print(tmp_str)

        return log_str

# %%
get_on_off_data = GetOnOffData2("/content/drive/Othercomputers/내 노트북/Forked_Models/Validation/Validation/_라벨_General_val_C/district_sample", "/content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/Apply_to_chC/getonoff/","/content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/Apply_to_chC/dataset",(0.8, 0.1))
# Out:
# 100%|██████████| 5/5 [00:03<00:00,  1.42it/s]

# %%
get_on_off_data.generateGetOnOffData()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# #A채널에 대해 학습된 모델 그대로 C채널에 적용해보기(모델 적용 첫 시도)
# 현재 경로 안에 evaluate.py, utils 폴더, dataset 폴더, output 폴더가 있어야 한다. (output 폴더는 로그를 위한 폴더로 비어있어도 됌)

# %%
# %cd "/content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/Apply_to_chC"
# Out:
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B

# %%
# !python "evaluate.py"
# Out:
# 2023-04-17 15:50:27.801568: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# [Timestamp: 2023-04-18 00:50:29 KST+0900] 개발 환경 정보
# OS:            Ubuntu 20.04.5 LTS
# CPU:           Intel(R) Xeon(R) CPU @ 2.00GHz
# GPU_0:         Tesla T4
# Memory:        13297184 kB
# Storage:       180.00 GiB
# TensorFlow:    2.12.0
# Keras:         2.12.0
# Python:        3.9.16
#
# [Timestamp: 2023-04-18 00:50:29 KST+0900] Test 데이터 정보 가져오기 시작
# [Timestamp: 2023-04-18 00:50:30 KST+0900] Test 데이터 목록
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_364.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_365.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_366.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_367.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_368.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_369.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_370.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_371.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_372.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_373.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_374.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_375.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_376.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_377.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_378.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_379.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_380.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_381.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_382.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_383.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_384.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_385.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_386.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_387.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_388.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_389.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_390.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_391.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_392.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_393.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_394.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_395.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_396.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_397.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_398.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_399.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_400.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_401.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_402.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_on_403.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_256.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_257.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_258.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_259.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_260.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_261.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_262.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_263.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_264.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_265.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_266.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_267.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_268.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_269.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_270.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_271.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_272.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_273.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_274.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_275.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_276.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_277.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_278.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_279.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_280.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_281.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_282.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_283.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_284.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_285.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_286.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_287.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_288.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_289.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_290.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_291.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_292.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_293.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_294.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_295.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_296.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_297.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_298.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_299.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_300.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_301.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_302.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_303.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_304.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_305.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_306.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_307.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_308.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_309.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_310.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_311.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_312.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_313.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_314.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_315.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_316.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_317.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_318.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_319.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_320.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_321.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_322.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_323.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_324.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_325.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_326.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_327.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_328.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_329.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_330.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_331.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_332.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_333.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_334.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_335.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_336.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_337.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_338.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_339.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_340.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_341.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_342.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_343.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_344.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_345.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_346.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_347.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_348.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_349.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_350.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_351.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_352.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_353.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_354.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_355.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_356.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_357.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_358.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_359.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_360.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_361.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_362.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_363.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_364.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_365.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_366.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_367.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_368.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_369.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_370.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_371.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_372.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_373.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_374.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_375.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_376.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_377.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_378.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_379.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_380.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_381.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_382.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_383.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_384.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_385.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_386.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_387.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_388.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_389.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_390.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_391.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_392.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_393.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_394.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_395.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_396.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_397.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_398.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_399.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_400.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_401.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_402.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_403.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_404.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_405.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_406.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_407.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_408.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_409.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_410.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_411.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_412.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_413.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_414.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_415.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_416.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_417.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_418.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_419.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_420.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_421.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_422.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_423.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_424.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_425.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_426.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_427.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_428.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_429.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_430.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_431.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_432.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_433.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_434.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_435.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_436.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_437.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_438.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_439.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_440.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_441.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_442.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_443.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_444.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_445.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_446.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_447.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_448.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_449.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_450.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_451.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_452.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_453.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_454.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_455.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_456.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_457.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_458.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_459.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_460.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_461.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_462.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_463.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_464.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_465.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_466.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_467.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_468.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_469.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_470.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_471.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_472.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_473.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_474.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_475.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_476.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_477.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_478.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_479.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_480.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_481.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_482.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_483.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_484.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_485.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_486.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_487.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_488.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_489.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_490.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_491.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_492.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_493.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_494.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_495.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_496.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_497.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_498.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_499.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_500.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_501.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_502.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_503.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_504.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_505.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_506.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_507.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_508.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_509.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_510.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_511.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_512.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_513.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_514.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_515.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_516.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_517.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_518.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_519.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_520.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_521.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_522.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_523.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_524.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_525.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_526.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_527.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_528.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_529.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_530.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_531.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_532.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_533.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_534.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_535.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_536.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_537.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_538.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_539.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_540.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_541.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_542.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_543.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_544.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_545.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_546.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_547.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_548.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_549.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_550.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_551.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_552.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_553.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_554.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_555.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_556.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_557.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_558.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_559.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_560.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_561.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_562.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_563.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_564.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_565.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_566.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_567.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_568.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_569.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_570.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_571.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_572.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_573.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_574.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/get_off_575.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_738.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_739.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_740.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_741.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_742.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_743.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_744.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_745.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_746.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_747.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_748.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_749.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_750.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_751.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_752.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_753.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_754.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_755.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_756.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_757.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_758.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_759.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_760.json
# ...
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:36 KST+0900] 765. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1142.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:36 KST+0900] 766. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1143.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:36 KST+0900] 767. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1144.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:36 KST+0900] 768. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1145.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:36 KST+0900] 769. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1146.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:36 KST+0900] 770. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1147.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:36 KST+0900] 771. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1148.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:36 KST+0900] 772. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1149.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:36 KST+0900] 773. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1150.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:37 KST+0900] 774. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1151.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:37 KST+0900] 775. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1152.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:37 KST+0900] 776. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1153.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:37 KST+0900] 777. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1154.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:37 KST+0900] 778. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1155.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:37 KST+0900] 779. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1156.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:37 KST+0900] 780. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1157.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:37 KST+0900] 781. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1158.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:37 KST+0900] 782. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1159.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:37 KST+0900] 783. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1160.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:37 KST+0900] 784. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1161.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:37 KST+0900] 785. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1162.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:37 KST+0900] 786. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1163.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:37 KST+0900] 787. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1164.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:37 KST+0900] 788. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1165.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:38 KST+0900] 789. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1166.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:38 KST+0900] 790. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1167.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:38 KST+0900] 791. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1168.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:38 KST+0900] 792. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1169.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:38 KST+0900] 793. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1170.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:38 KST+0900] 794. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1171.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:38 KST+0900] 795. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1172.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:38 KST+0900] 796. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1173.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:38 KST+0900] 797. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1174.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:38 KST+0900] 798. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1175.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:38 KST+0900] 799. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1176.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:38 KST+0900] 800. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1177.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:38 KST+0900] 801. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1178.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:38 KST+0900] 802. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1179.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:38 KST+0900] 803. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1180.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:38 KST+0900] 804. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1181.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:39 KST+0900] 805. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1182.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:39 KST+0900] 806. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1183.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:39 KST+0900] 807. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1184.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:39 KST+0900] 808. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1185.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:39 KST+0900] 809. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1186.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:39 KST+0900] 810. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1187.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:39 KST+0900] 811. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1188.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:39 KST+0900] 812. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1189.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:39 KST+0900] 813. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1190.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:39 KST+0900] 814. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1191.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:39 KST+0900] 815. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1192.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:39 KST+0900] 816. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1193.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:39 KST+0900] 817. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1194.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:39 KST+0900] 818. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1195.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:39 KST+0900] 819. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1196.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:40 KST+0900] 820. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1197.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:40 KST+0900] 821. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1198.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:40 KST+0900] 822. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1199.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:40 KST+0900] 823. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1200.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:40 KST+0900] 824. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1201.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:40 KST+0900] 825. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1202.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:40 KST+0900] 826. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1203.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:40 KST+0900] 827. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1204.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:40 KST+0900] 828. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1205.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:40 KST+0900] 829. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1206.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:40 KST+0900] 830. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1207.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:40 KST+0900] 831. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1208.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:40 KST+0900] 832. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1209.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:40 KST+0900] 833. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1210.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:40 KST+0900] 834. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1211.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:40 KST+0900] 835. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1212.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:41 KST+0900] 836. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1213.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get Off
#
# [Timestamp: 2023-04-18 00:51:41 KST+0900] 837. /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/channel_B/dataset/test/idle_1214.json Test 데이터 인풋 결과
# 정답: Idle
# 예측: Get On
#
# [Timestamp: 2023-04-18 00:51:41 KST+0900] 전체 Test 데이터 종합 평가 시작
# [Timestamp: 2023-04-18 00:51:41 KST+0900] 전체 Test 데이터 종합 혼동 행렬 결과
#                               Predicted Class
#                               Get On         Get Off        Idle
# True Class     Get On         25             0              15
#                Get Off        72             109            139
#                Idle           42             51             384
#
#
# [Timestamp: 2023-04-18 00:51:41 KST+0900] 전체 Test 데이터 종합 결과
#                Precision      Recall         F1-score
# Get On         0.18           0.62           0.28
# Get Off        0.68           0.34           0.45
# Idle           0.71           0.81           0.76
#
# Total          0.68           0.62           0.62
#
#
# [Timestamp: 2023-04-18 00:51:41 KST+0900] 모델 평가 종료
