# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성"
# Out:
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성

# %%
# %cd "docker_files/fs_get_on_off"
# Out:
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/docker_files/fs_get_on_off

# %%
# !python "evaluate.py"
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/docker_files/fs_get_on_off/dataset/test/get_off_58108.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/docker_files/fs_get_on_off/dataset/test/get_off_58109.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/docker_files/fs_get_on_off/dataset/test/get_off_58110.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/docker_files/fs_get_on_off/dataset/test/get_off_58111.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/docker_files/fs_get_on_off/dataset/test/get_off_58112.json
# /content/drive/Othercomputers/내 노트북/Forked_Models/승객 승하차 분류 유효성/docker_files/fs_get_on_off/dataset/test/get_off_58113.json
# ...
