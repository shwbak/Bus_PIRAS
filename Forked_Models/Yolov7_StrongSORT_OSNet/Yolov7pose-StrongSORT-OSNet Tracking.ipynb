# %% [markdown]
# # Setup
#
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "drive/Othercomputers/내 노트북/Forked_Models/Yolov7_StrongSORT_OSNet"
# Out:
# /content/drive/Othercomputers/내 노트북/Forked_Models/Yolov7_StrongSORT_OSNet

# %%
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 2.0.0+cu118 (CPU)

# %% [markdown]
# # Download data
#
# Get test video from repo and extract the first 2 seconds of it

# %%
# get yolov5m model trained on the crowd-human dataset
# !wget -nc https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt -O "/content/drive/Othercomputers/내 노트북/Forked_Models/Yolov7_StrongSORT_OSNet/yolov7.pt"

# get the test video from the repo
#!wget -nc https://github.com/mikel-brostrom/Yolov5_StrongSORT_OSNet/releases/download/v.2.0/test.avi
# extract 3 seconds worth of video frames of it
#!yes | ffmpeg -ss 00:00:00 -i test.avi -t 00:00:02 -c copy out.avi
# Out:
# File ‘/content/drive/Othercomputers/내 노트북/Forked_Models/Yolov7_StrongSORT_OSNet/yolov7.pt’ already there; not retrieving.

# %% [markdown]
# #1. District Sample 1

# %% [markdown]
# ## Run inference on video
#
# The ``cv2.imshow()`` and ``cv.imshow()`` functions from the [opencv-python](https://github.com/skvark/opencv-python) package are incompatible with Jupyter notebook; see https://github.com/jupyter/notebook/issues/3935.
#
# Hence we chose to save it to file in this notebook. Locally you can use the ``--show-vid`` flag in order visualize the tracking in real-time

# %%
# !python track.py --yolo-weights "/content/drive/Othercomputers/내 노트북/Forked_Models/Yolov7_StrongSORT_OSNet/yolov7.pt" --strong-sort-weights osnet_x0_25_msmt17.pt --source "/content/drive/Othercomputers/내 노트북/Forked_Models/Validation/Validation/_원천_General_val_C/district_sample/*/*.jpg" --save-vid --conf-thres 0.15 --device 0 --classes 0
# Out:
# /content/drive/Othercomputers/내 노트북/Forked_Models/Yolov7_StrongSORT_OSNet/strong_sort/deep/reid/torchreid/metrics/rank.py:11: UserWarning: Cython evaluation (very fast so highly recommended) is unavailable, now use python evaluation.
#   warnings.warn(
# 2023-04-17 17:28:24.639595: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-17 17:28:25.492808: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# Model: osnet_x0_25
# - params: 203,568
# - flops: 82,316,000
# Successfully loaded pretrained weights from "osnet_x0_25_msmt17.pt"
# ...

# %% [markdown]
# # Show results
#
# https://stackoverflow.com/questions/60977179/how-to-play-avi-file-in-google-colab
#
# Convert avi to mp4

# %%
# !ffmpeg -i "/content/drive/Othercomputers/내 노트북/Forked_Models/Yolov7_StrongSORT_OSNet/runs/track/exp9/[district]attend_057C.mp4" sample_video.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %% [markdown]
# Get the file content into data_url

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open('sample_video.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

# %% [markdown]
# Display it with HTML

# %%
HTML("""
<video controls width="900">
      <source src="%s" type="video/mp4">
</video>
""" % data_url)

# %% [markdown]
# #2. District Sample 2

# %% [markdown]
# ## Run inference on video
#
# The ``cv2.imshow()`` and ``cv.imshow()`` functions from the [opencv-python](https://github.com/skvark/opencv-python) package are incompatible with Jupyter notebook; see https://github.com/jupyter/notebook/issues/3935.
#
# Hence we chose to save it to file in this notebook. Locally you can use the ``--show-vid`` flag in order visualize the tracking in real-time

# %%
# !python track.py --yolo-weights "/content/drive/Othercomputers/내 노트북/Forked_Models/Yolov7_StrongSORT_OSNet/yolov7.pt" --strong-sort-weights osnet_x0_25_msmt17.pt --source "/content/drive/Othercomputers/내 노트북/Forked_Models/Validation/Validation/_원천_General_val_C/district_sample2/" --save-vid --conf-thres 0.15 --device 0 --classes 0
# Out:
# /content/drive/Othercomputers/내 노트북/Forked_Models/Yolov7_StrongSORT_OSNet/strong_sort/deep/reid/torchreid/metrics/rank.py:11: UserWarning: Cython evaluation (very fast so highly recommended) is unavailable, now use python evaluation.
#   warnings.warn(
# 2023-04-25 00:44:50.844023: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-25 00:44:52.083919: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# Model: osnet_x0_25
# - params: 203,568
# - flops: 82,316,000
# Successfully loaded pretrained weights from "osnet_x0_25_msmt17.pt"
# ...

# %% [markdown]
# # Show results
#
# https://stackoverflow.com/questions/60977179/how-to-play-avi-file-in-google-colab
#
# Convert avi to mp4

# %%
# !ffmpeg -i "/content/drive/Othercomputers/내 노트북/Forked_Models/Yolov7_StrongSORT_OSNet/runs/track/exp12/district_sample2.mp4" sample_video3.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %% [markdown]
# Get the file content into data_url

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open('sample_video3.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

# %% [markdown]
# Display it with HTML

# %%
HTML("""
<video controls width="1000">
      <source src="%s" type="video/mp4">
</video>
""" % data_url)

# %% [markdown]
# #3. Pose 모델로 Tracking을 한다면?

# %% [markdown]
# ## Run inference on video
#
# The ``cv2.imshow()`` and ``cv.imshow()`` functions from the [opencv-python](https://github.com/skvark/opencv-python) package are incompatible with Jupyter notebook; see https://github.com/jupyter/notebook/issues/3935.
#
# Hence we chose to save it to file in this notebook. Locally you can use the ``--show-vid`` flag in order visualize the tracking in real-time

# %%
# %cd "/content/drive/Othercomputers/내 노트북/Forked_Models/Yolov7_StrongSORT_OSNet"
# Out:
# /content/drive/Othercomputers/내 노트북/Forked_Models/Yolov7_StrongSORT_OSNet

# %%
# !python track_for_yolopose.py --yolo-weights "/content/drive/Othercomputers/내 노트북/Forked_Models/Yolov7_StrongSORT_OSNet/yolov7/yolov7-w6-pose.pt" --strong-sort-weights osnet_x0_25_msmt17.pt --source "/content/drive/Othercomputers/내 노트북/Forked_Models/Validation/Validation/_원천_General_val_C/district_sample2/" --save-vid --conf-thres 0.15 --device 0 --classes 0
#yolopose로 모델 바꿔서 돌리는 것 성공!
# Out:
# /content/drive/Othercomputers/내 노트북/Forked_Models/Yolov7_StrongSORT_OSNet/strong_sort/deep/reid/torchreid/metrics/rank.py:11: UserWarning: Cython evaluation (very fast so highly recommended) is unavailable, now use python evaluation.
#   warnings.warn(
# 2023-05-07 10:32:01.287691: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-07 10:32:02.448364: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# cpu
# Loading model: /content/drive/Othercomputers/내 노트북/Forked_Models/Yolov7_StrongSORT_OSNet/yolov7/yolov7-w6-pose.pt
# Model: osnet_x0_25
# - params: 203,568
# - flops: 82,316,000
# Successfully loaded pretrained weights from "osnet_x0_25_msmt17.pt"
# ...

# %% [markdown]
# # Show results
#
# https://stackoverflow.com/questions/60977179/how-to-play-avi-file-in-google-colab
#
# Convert avi to mp4

# %%
# !ffmpeg -i "/content/drive/Othercomputers/내 노트북/Forked_Models/Yolov7_StrongSORT_OSNet/runs/track/exp59/district_sample2.mp4" sample_video5.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %% [markdown]
# Get the file content into data_url

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open('sample_video5.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

# %% [markdown]
# Display it with HTML

# %%
HTML("""
<video controls width="1000">
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
