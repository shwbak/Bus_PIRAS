# %% [markdown]
# # Setup
#
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "drive/Othercomputers/내 노트북/Forked_Models/Yolov7_StrongSORT_OSNet"
# Out:
# /content/drive/Othercomputers/내 노트북/Forked_Models/Yolov7_StrongSORT_OSNet

# %%
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 2.0.0+cu118 (Tesla T4)

# %% [markdown]
# # Download data
#
# Get test video from repo and extract the first 2 seconds of it

# %%
# get yolov5m model trained on the crowd-human dataset
# !wget -nc https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt -O "/content/drive/Othercomputers/내 노트북/Forked_Models/Yolov7_StrongSORT_OSNet/yolov7.pt"

# get the test video from the repo
# !wget -nc https://github.com/mikel-brostrom/Yolov5_StrongSORT_OSNet/releases/download/v.2.0/test.avi
# extract 3 seconds worth of video frames of it
# !yes | ffmpeg -ss 00:00:00 -i test.avi -t 00:00:02 -c copy out.avi
# Out:
# /content/drive/Othercomputers/내: Operation not supported
# File ‘test.avi’ already there; not retrieving.
#
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, matroska,webm, from 'test.avi':
#   Metadata:
#     COMPATIBLE_BRANDS: isomiso2mp41
#     MAJOR_BRAND     : isom
#     MINOR_VERSION   : 512
#     ENCODER         : Lavf57.83.100
#   Duration: 00:00:35.00, start: 0.000000, bitrate: 1164 kb/s
#     Stream #0:0: Video: vp9 (Profile 0), yuv420p(tv, progressive), 960x540, SAR 1:1 DAR 16:9, 30 fps, 30 tbr, 1k tbn, 1k tbc (default)
#     Metadata:
#       HANDLER_NAME    : VideoHandler
#       ENCODER         : Lavc57.107.100 libvpx-vp9
#       DURATION        : 00:00:35.000000000
# File 'out.avi' already exists. Overwrite ? [y/N] Output #0, avi, to 'out.avi':
#   Metadata:
#     COMPATIBLE_BRANDS: isomiso2mp41
#     MAJOR_BRAND     : isom
#     MINOR_VERSION   : 512
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Video: vp9 (Profile 0) (VP90 / 0x30395056), yuv420p(tv, progressive), 960x540 [SAR 1:1 DAR 16:9], q=2-31, 30 fps, 30 tbr, 60 tbn, 60 tbc (default)
#     Metadata:
#       HANDLER_NAME    : VideoHandler
#       ENCODER         : Lavc57.107.100 libvpx-vp9
#       DURATION        : 00:00:35.000000000
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# frame=   60 fps=0.0 q=-1.0 Lsize=     285kB time=00:00:01.98 bitrate=1177.7kbits/s speed= 334x
# video:277kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.061152%

# %% [markdown]
# ## Run inference on video
#
# The ``cv2.imshow()`` and ``cv.imshow()`` functions from the [opencv-python](https://github.com/skvark/opencv-python) package are incompatible with Jupyter notebook; see https://github.com/jupyter/notebook/issues/3935.
#
# Hence we chose to save it to file in this notebook. Locally you can use the ``--show-vid`` flag in order visualize the tracking in real-time

# %%
# !python track.py --yolo-weights "/content/drive/Othercomputers/내 노트북/Forked_Models/Yolov7_StrongSORT_OSNet/yolov7.pt" --strong-sort-weights osnet_x0_25_msmt17.pt --source sample_video/ --save-vid --conf-thres 0.05 --device 0 --classes 0
# Out:
# /content/drive/Othercomputers/내 노트북/Forked_Models/Yolov7_StrongSORT_OSNet/strong_sort/deep/reid/torchreid/metrics/rank.py:11: UserWarning: Cython evaluation (very fast so highly recommended) is unavailable, now use python evaluation.
#   warnings.warn(
# 2023-04-17 00:16:26.275902: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-17 00:16:27.443426: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Downloading https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt to /content/drive/Othercomputers/내 노트북/Forked_Models/Yolov7_StrongSORT_OSNet/yolov7.pt...
# 100% 72.1M/72.1M [00:01<00:00, 54.6MB/s]
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# Downloading...
# From: https://drive.google.com/uc?id=1Kkx2zW89jq_NETu4u42CFZTMVD5Hwm6e
# To: /content/drive/Othercomputers/내 노트북/Forked_Models/Yolov7_StrongSORT_OSNet/osnet_x0_25_msmt17.pt
# 100% 9.34M/9.34M [00:00<00:00, 17.2MB/s]
# Model: osnet_x0_25
# - params: 203,568
# - flops: 82,316,000
# Successfully loaded pretrained weights from "osnet_x0_25_msmt17.pt"
# ** The following layers are discarded due to unmatched keys or layer size: ['classifier.weight', 'classifier.bias']
# (1, 256, 128, 3)
# /usr/local/lib/python3.9/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 384x640 2 persons, Done. YOLO:(0.235s), StrongSORT:(0.041s)
# 384x640 2 persons, Done. YOLO:(0.032s), StrongSORT:(0.054s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.067s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.100s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.077s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.069s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.081s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.055s)
# 384x640 6 persons, Done. YOLO:(0.032s), StrongSORT:(0.088s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.091s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.078s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.073s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.060s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.071s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.074s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.069s)
# 384x640 5 persons, Done. YOLO:(0.033s), StrongSORT:(0.072s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.061s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.060s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.069s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.055s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.052s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.043s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.062s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.060s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.045s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.069s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.044s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.062s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.042s)
# 384x640 6 persons, Done. YOLO:(0.032s), StrongSORT:(0.083s)
# 384x640 6 persons, Done. YOLO:(0.032s), StrongSORT:(0.082s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.073s)
# 384x640 8 persons, Done. YOLO:(0.032s), StrongSORT:(0.121s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.059s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.057s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.044s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.045s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.049s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.046s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.047s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.044s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.045s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.045s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.055s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.044s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.066s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.059s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.063s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.081s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.069s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.064s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.045s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.085s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.066s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.056s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.087s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.088s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.104s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.106s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.102s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.078s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.108s)
# 384x640 2 persons, Done. YOLO:(0.032s), StrongSORT:(0.045s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.068s)
# 384x640 2 persons, Done. YOLO:(0.032s), StrongSORT:(0.043s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.060s)
# 384x640 2 persons, Done. YOLO:(0.032s), StrongSORT:(0.045s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.081s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.066s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.080s)
# 384x640 6 persons, Done. YOLO:(0.032s), StrongSORT:(0.128s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.105s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.103s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.125s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.055s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.059s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.044s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.065s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.084s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.047s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.069s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.053s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.056s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.056s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.044s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.057s)
# 384x640 2 persons, Done. YOLO:(0.032s), StrongSORT:(0.036s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.059s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.058s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.071s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.048s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.049s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.051s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.045s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.049s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.047s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.046s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.050s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.047s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.046s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.061s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.055s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.045s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.071s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.044s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.047s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.070s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.082s)
# 384x640 4 persons, Done. YOLO:(0.031s), StrongSORT:(0.061s)
# 384x640 4 persons, Done. YOLO:(0.031s), StrongSORT:(0.066s)
# 384x640 3 persons, Done. YOLO:(0.031s), StrongSORT:(0.048s)
# 384x640 3 persons, Done. YOLO:(0.031s), StrongSORT:(0.059s)
# 384x640 3 persons, Done. YOLO:(0.031s), StrongSORT:(0.046s)
# 384x640 3 persons, Done. YOLO:(0.031s), StrongSORT:(0.044s)
# 384x640 4 persons, Done. YOLO:(0.031s), StrongSORT:(0.063s)
# 384x640 3 persons, Done. YOLO:(0.031s), StrongSORT:(0.045s)
# 384x640 4 persons, Done. YOLO:(0.031s), StrongSORT:(0.062s)
# 384x640 3 persons, Done. YOLO:(0.031s), StrongSORT:(0.043s)
# 384x640 4 persons, Done. YOLO:(0.031s), StrongSORT:(0.060s)
# 384x640 6 persons, Done. YOLO:(0.031s), StrongSORT:(0.083s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.075s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.063s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.074s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.064s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.076s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.081s)
# 384x640 6 persons, Done. YOLO:(0.032s), StrongSORT:(0.090s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.045s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.048s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.046s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.064s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.045s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.044s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.044s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.078s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.056s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.052s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.045s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.071s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.045s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.046s)
# 384x640 6 persons, Done. YOLO:(0.032s), StrongSORT:(0.083s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.099s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.065s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.095s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.080s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.087s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.062s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.076s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.093s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.069s)
# 384x640 4 persons, Done. YOLO:(0.033s), StrongSORT:(0.078s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.078s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.067s)
# 384x640 4 persons, Done. YOLO:(0.033s), StrongSORT:(0.091s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.081s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.062s)
# 384x640 6 persons, Done. YOLO:(0.032s), StrongSORT:(0.123s)
# 384x640 6 persons, Done. YOLO:(0.032s), StrongSORT:(0.132s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.066s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.078s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.102s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.079s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.068s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.074s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.064s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.060s)
# 384x640 6 persons, Done. YOLO:(0.032s), StrongSORT:(0.095s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.045s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.057s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.072s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.058s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.049s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.045s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.049s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.045s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.046s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.044s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.047s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.045s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.065s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.045s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.062s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.045s)
# 384x640 7 persons, Done. YOLO:(0.032s), StrongSORT:(0.117s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.065s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.047s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.067s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.079s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.062s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.052s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.055s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.047s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.066s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.060s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.063s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.046s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.063s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.046s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.044s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.061s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.047s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.066s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.060s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.055s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.046s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.052s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.054s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.049s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.052s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.044s)
# 384x640 6 persons, Done. YOLO:(0.032s), StrongSORT:(0.098s)
# 384x640 2 persons, Done. YOLO:(0.032s), StrongSORT:(0.031s)
# 384x640 2 persons, Done. YOLO:(0.032s), StrongSORT:(0.038s)
# 384x640 2 persons, Done. YOLO:(0.032s), StrongSORT:(0.034s)
# 384x640 2 persons, Done. YOLO:(0.032s), StrongSORT:(0.036s)
# 384x640 2 persons, Done. YOLO:(0.032s), StrongSORT:(0.031s)
# 384x640 2 persons, Done. YOLO:(0.032s), StrongSORT:(0.037s)
# 384x640 2 persons, Done. YOLO:(0.032s), StrongSORT:(0.033s)
# 384x640 2 persons, Done. YOLO:(0.032s), StrongSORT:(0.041s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.064s)
# 384x640 2 persons, Done. YOLO:(0.032s), StrongSORT:(0.035s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.048s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.072s)
# 384x640 2 persons, Done. YOLO:(0.032s), StrongSORT:(0.032s)
# 384x640 2 persons, Done. YOLO:(0.032s), StrongSORT:(0.031s)
# 384x640 2 persons, Done. YOLO:(0.032s), StrongSORT:(0.033s)
# 384x640 2 persons, Done. YOLO:(0.032s), StrongSORT:(0.032s)
# 384x640 2 persons, Done. YOLO:(0.032s), StrongSORT:(0.035s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.049s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.044s)
# 384x640 2 persons, Done. YOLO:(0.032s), StrongSORT:(0.040s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.067s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.068s)
# 384x640 3 persons, Done. YOLO:(0.034s), StrongSORT:(0.065s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.080s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.067s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.063s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.066s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.077s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.060s)
# 384x640 6 persons, Done. YOLO:(0.032s), StrongSORT:(0.127s)
# 384x640 2 persons, Done. YOLO:(0.032s), StrongSORT:(0.043s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.064s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.064s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.083s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.081s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.060s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.090s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.064s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.130s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.113s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.066s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.050s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.073s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.048s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.058s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.061s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.044s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.045s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.046s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.060s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.050s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.045s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.044s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.078s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.058s)
# 384x640 4 persons, Done. YOLO:(0.031s), StrongSORT:(0.060s)
# 384x640 4 persons, Done. YOLO:(0.031s), StrongSORT:(0.061s)
# 384x640 5 persons, Done. YOLO:(0.031s), StrongSORT:(0.078s)
# 384x640 5 persons, Done. YOLO:(0.031s), StrongSORT:(0.068s)
# 384x640 5 persons, Done. YOLO:(0.031s), StrongSORT:(0.078s)
# 384x640 5 persons, Done. YOLO:(0.031s), StrongSORT:(0.073s)
# 384x640 5 persons, Done. YOLO:(0.031s), StrongSORT:(0.072s)
# 384x640 3 persons, Done. YOLO:(0.031s), StrongSORT:(0.044s)
# 384x640 2 persons, Done. YOLO:(0.031s), StrongSORT:(0.037s)
# 384x640 4 persons, Done. YOLO:(0.031s), StrongSORT:(0.055s)
# 384x640 4 persons, Done. YOLO:(0.031s), StrongSORT:(0.059s)
# 384x640 3 persons, Done. YOLO:(0.031s), StrongSORT:(0.044s)
# 384x640 5 persons, Done. YOLO:(0.031s), StrongSORT:(0.076s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.073s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.063s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.048s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.061s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.060s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.045s)
# 384x640 2 persons, Done. YOLO:(0.032s), StrongSORT:(0.031s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.057s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.064s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.057s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.057s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.047s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.060s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.074s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.068s)
# 384x640 7 persons, Done. YOLO:(0.032s), StrongSORT:(0.104s)
# 384x640 7 persons, Done. YOLO:(0.032s), StrongSORT:(0.097s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.062s)
# 384x640 8 persons, Done. YOLO:(0.032s), StrongSORT:(0.115s)
# 384x640 3 persons, Done. YOLO:(0.032s), StrongSORT:(0.048s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.077s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.059s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.058s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.056s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.083s)
# 384x640 5 persons, Done. YOLO:(0.032s), StrongSORT:(0.072s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.066s)
# 384x640 4 persons, Done. YOLO:(0.032s), StrongSORT:(0.065s)
# Speed: 0.5ms pre-process, 32.8ms inference, 2.3ms NMS, 62.9ms strong sort update per image at shape (1, 3, 640, 640)
# Results saved to runs/track/exp4

# %% [markdown]
# # Show results
#
# https://stackoverflow.com/questions/60977179/how-to-play-avi-file-in-google-colab
#
# Convert avi to mp4

# %%
# !ffmpeg -i "/content/drive/Othercomputers/내 노트북/Forked_Models/Yolov7_StrongSORT_OSNet/runs/track/exp4/sample_video.mp4" sample_video.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/content/drive/Othercomputers/내 노트북/Forked_Models/Yolov7_StrongSORT_OSNet/runs/track/exp4/sample_video.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:10.30, start: 0.000000, bitrate: 19289 kb/s
#     Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 1920x1080 [SAR 1:1 DAR 16:9], 19287 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x561e295d35c0] using SAR=1/1
# [libx264 @ 0x561e295d35c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x561e295d35c0] profile High, level 4.0
# [libx264 @ 0x561e295d35c0] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'sample_video.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1920x1080 [SAR 1:1 DAR 16:9], q=-1--1, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  309 fps=7.0 q=-1.0 Lsize=    6446kB time=00:00:10.20 bitrate=5176.7kbits/s speed=0.231x
# video:6441kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.063826%
# [libx264 @ 0x561e295d35c0] frame I:2     Avg QP:22.04  size:137399
# [libx264 @ 0x561e295d35c0] frame P:143   Avg QP:23.50  size: 31143
# [libx264 @ 0x561e295d35c0] frame B:164   Avg QP:25.78  size: 11385
# [libx264 @ 0x561e295d35c0] consecutive B-frames: 24.9%  9.7%  9.7% 55.7%
# [libx264 @ 0x561e295d35c0] mb I  I16..4: 18.1% 74.2%  7.7%
# [libx264 @ 0x561e295d35c0] mb P  I16..4:  2.9%  8.5%  0.8%  P16..4: 43.4%  8.7%  6.7%  0.0%  0.0%    skip:28.9%
# [libx264 @ 0x561e295d35c0] mb B  I16..4:  1.3%  4.6%  0.4%  B16..8: 27.0%  2.9%  0.5%  direct: 1.7%  skip:61.6%  L0:53.3% L1:44.7% BI: 2.0%
# [libx264 @ 0x561e295d35c0] 8x8 transform intra:71.1% inter:78.8%
# [libx264 @ 0x561e295d35c0] coded y,uvDC,uvAC intra: 46.5% 69.1% 10.5% inter: 13.1% 22.8% 1.1%
# [libx264 @ 0x561e295d35c0] i16 v,h,dc,p: 44% 24% 21% 11%
# [libx264 @ 0x561e295d35c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 23% 17% 41%  3%  3%  3%  3%  3%  3%
# [libx264 @ 0x561e295d35c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 34% 22% 11%  4%  7%  8%  5%  5%  4%
# [libx264 @ 0x561e295d35c0] i8c dc,h,v,p: 44% 24% 29%  4%
# [libx264 @ 0x561e295d35c0] Weighted P-Frames: Y:0.7% UV:0.0%
# [libx264 @ 0x561e295d35c0] ref P L0: 59.8% 10.8% 19.9%  9.5%  0.0%
# [libx264 @ 0x561e295d35c0] ref B L0: 76.8% 16.3%  6.9%
# [libx264 @ 0x561e295d35c0] ref B L1: 93.3%  6.7%
# [libx264 @ 0x561e295d35c0] kb/s:5122.64

# %% [markdown]
# Get the file content into data_url

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open('sample_video.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

# %% [markdown]
# Display it with HTML

# %%
HTML("""
<video controls width="600">
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
