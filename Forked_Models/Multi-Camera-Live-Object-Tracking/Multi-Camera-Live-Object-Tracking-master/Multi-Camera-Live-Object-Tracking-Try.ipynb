# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd "/content/drive/Othercomputers/내 노트북/Forked_Models/Multi-Camera-Live-Object-Tracking/Multi-Camera-Live-Object-Tracking-master/object_counting"
# Out:
# /content/drive/Othercomputers/내 노트북/Forked_Models/Multi-Camera-Live-Object-Tracking/Multi-Camera-Live-Object-Tracking-master/object_counting

# %%
# !pip install flask-ngrok
# !pip install streamlit -q
# !pip install pyngrok
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 61.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 24.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 kB 17.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 10.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 85.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.2 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 680.1/680.1 kB 11.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
! nvidia-smi
# Out:
# Tue Apr 11 06:06:51 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   64C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install colab-ssh
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from colab_ssh import launch_ssh
launch_ssh("2O6kIDCbMYA0yMBEwHglhc6KT45_26LU1ZfPBevUi7vLBigKF", "1111")
# Out:
# ...
# we highly recommend that update your code by following this documentation https://github.com/WassimBenzarti/colab-ssh#getting-started
# Successfully running 8.tcp.ngrok.io:15065
# [Optional] You can also connect with VSCode SSH Remote extension using this configuration:
#
#   Host google_colab_ssh
#     HostName 8.tcp.ngrok.io
#     User root
#     Port 15065

# %%
#!pip uninstall pyngrok

# %%
from pyngrok import ngrok

# %%
ngrok.set_auth_token("2O6kIDCbMYA0yMBEwHglhc6KT45_26LU1ZfPBevUi7vLBigKF")

# %%
# !nohup streamlit run app.py --server.port 80 &
#!nohup streamlit run video_streamer.py --server.port 8080 &
# Out:
# nohup: appending output to 'nohup.out'

# %%
url = ngrok.connect(port = "80")
url
# Out:
# WARNING:pyngrok.process.ngrok:t=2023-04-12T00:05:23+0000 lvl=warn msg="can't bind default web address, trying alternatives" obj=web addr=127.0.0.1:4040
# ERROR:pyngrok.process.ngrok:t=2023-04-12T00:05:23+0000 lvl=eror msg="failed to auth" obj=tunnels.session err="Your account is limited to 1 simultaneous ngrok agent session.\nActive ngrok agent sessions in region 'us':\n  - ts_2OIpOKmPOKGtDxjSiKMPrkO3L1b (35.202.93.28)\r\n\r\nERR_NGROK_108\r\n"
# ---------------------------------------------------------------------------
# PyngrokNgrokError                         Traceback (most recent call last)
# <ipython-input-8-842d66cbd33a> in <cell line: 1>()
# ----> 1 url = ngrok.connect(port = "80")
#       2 url
#
# /usr/local/lib/python3.9/dist-packages/pyngrok/ngrok.py in connect(addr, proto, name, pyngrok_config, **options)
#     265         options.pop("bind_tls")
#     266
# --> 267     api_url = get_ngrok_process(pyngrok_config).api_url
#     268
# ...

# %%
ngrok.kill()
